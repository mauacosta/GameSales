# %%
(require '[clojupyter.misc.helper :as helper])
(helper/add-dependencies '[incanter "1.5.7"])
(use '(incanter core stats charts io datasets ))
# Out:
# nil

# %%
(require '[cemerick.pomegranate :refer [add-dependencies]])
(add-dependencies :coordinates '[[org.clojure/data.csv "0.1.2"]])
(require '[clojure.data.csv :as csv])
# Out:
# nil

# %%
(def games_csv (read-dataset "games.csv" :header true))
# Out:
# #'user/games_csv

# %%
(def games (drop 1 (with-open [in-file (clojure.java.io/reader "games.csv")]
    (doall
         (csv/read-csv in-file)
    )
)))

(defrecord Game [game jp_sales global_sales])

(defn toInt [n] (Integer. n))
(defn toDouble [n] (Double. n))
(defn square [n] (* n n))
(defn avg [items] (/ (reduce + items) (count items)))

(defn gameToRecord [g] 
    (Game. 
         (nth g 0) 
         (toDouble (if (empty? (nth g 7)) "0" (nth g 7)))
         (toDouble (if (empty? (nth g 9)) "0" (nth g 9))) 
    )
)

(def data (map #(gameToRecord %) games))

(ns-unmap (find-ns 'user) 'games)

(def shuffledData (shuffle data))
(def trainingData (take (int (* (count data) 0.8)) shuffledData))
(def testsData (take-last (int (* (count data) 0.2)) shuffledData))

(ns-unmap (find-ns 'user) 'games)
(ns-unmap (find-ns 'user) 'shuffledData)
# Out:
# nil

# %%
(def ventasJapon (map #(:jp_sales %) trainingData))
(def ventasGlobal (map #(:global_sales %) trainingData))
# Out:
# #'user/ventasGlobal

# %%
(-> (scatter-plot ventasJapon
                 ventasGlobal
                 :x-label "Ventas Japón" :y-label "Ventas Mundiales")
    (.createBufferedImage 600 400)
)

# %%
(def avgJpn (avg ventasJapon))
(def avgGlo (avg ventasGlobal))
(def n (count ventasJapon))

(def m 
    (/ 
        (reduce + (map #(* (- (:jp_sales %) avgJpn) (- (:global_sales %) avgGlo)) trainingData))
        (reduce + (map #(square (- (:jp_sales %) avgJpn)) trainingData))
    )
)
(def c (- avgGlo (* avgJpn m)))

(defn eq [x] (+ (* x m) c) )
# Out:
# #'user/eq

# %%
(-> (scatter-plot ventasJapon 
                  ventasGlobal
                  :x-label "Ventas Japón" :y-label "Ventas Mundiales")
    (add-function eq 0 (+ (reduce max ventasJapon) 1))
    (.createBufferedImage 600 400)
)

# %%
testsData
# Out:
# (#user.Game{:game "Halo Wars", :jp_sales 0.04, :global_sales 2.62} #user.Game{:game "America's Next Top Model", :jp_sales 0.0, :global_sales 0.07} #user.Game{:game "Pro Evolution Soccer 2015", :jp_sales 0.11, :global_sales 0.75} #user.Game{:game "Call of Duty: Modern Warfare 3", :jp_sales 0.49, :global_sales 13.32} #user.Game{:game "God of War Collection", :jp_sales 0.06, :global_sales 2.6} #user.Game{:game "Battlefield 2: Modern Combat", :jp_sales 0.0, :global_sales 0.56} #user.Game{:game "Kakyuusei", :jp_sales 0.28, :global_sales 0.28} #user.Game{:game "Cool Boarders 2", :jp_sales 0.2, :global_sales 2.25} #user.Game{:game "New Play Control! Pikmin", :jp_sales 0.19, :global_sales 0.64} #user.Game{:game "Interplay Sports Baseball 2000", :jp_sales 0.0, :global_sales 0.06} #user.Game{:game "Shinseiki Evangelion: Battle Orchestra Portable", :jp_sales 0.01, :global_sales 0.01} #user.Game{:game "Pac-Man World 3", :jp_sales 0.0, :global_sales 0.15} #user.Game{:game "Cabela's African Safari", :jp_sales 0.0, :global_sales 0.05} #user.Game{:game "Medal of Honor: Warfighter", :jp_sales 0.06, :global_sales 1.41} #user.Game{:game "Little League World Series Baseball 2009", :jp_sales 0.0, :global_sales 0.13} #user.Game{:game "Mercenaries: Playground of Destruction", :jp_sales 0.0, :global_sales 0.68} #user.Game{:game "Children of Mana", :jp_sales 0.29, :global_sales 0.48} #user.Game{:game "Gladius", :jp_sales 0.0, :global_sales 0.2} #user.Game{:game "Destroy All Humans! Path of the Furon", :jp_sales 0.0, :global_sales 0.13} #user.Game{:game "Homeworld", :jp_sales 0.0, :global_sales 0.02} #user.Game{:game "Pinobee: Wings of Adventure", :jp_sales 0.0, :global_sales 0.08} #user.Game{:game "Victory Zone", :jp_sales 0.1, :global_sales 0.11} #user.Game{:game "Suikoden: Tsumugareshi Hyakunen no Toki", :jp_sales 0.13, :global_sales 0.13} #user.Game{:game "Memories Off: Yubikiri no Kioku", :jp_sales 0.02, :global_sales 0.02} #user.Game{:game "LEGO Racers", :jp_sales 0.0, :global_sales 0.71} #user.Game{:game "Guitar Hero 5", :jp_sales 0.0, :global_sales 1.55} #user.Game{:game "Metroid Prime: Trilogy", :jp_sales 0.0, :global_sales 0.61} #user.Game{:game "Syberia", :jp_sales 0.0, :global_sales 0.1} #user.Game{:game "Beach Spikers: Virtua Beach Volleyball", :jp_sales 0.0, :global_sales 0.1} #user.Game{:game "Puyo Puyo Tetris", :jp_sales 0.11, :global_sales 0.11} #user.Game{:game "Postman Pat: Special Delivery Service", :jp_sales 0.0, :global_sales 0.01} #user.Game{:game "Hisshou Pachinko*Pachi-Slot Kouryaku Series DS Vol. 4: Shinseiki Evangelion - Saigo no Mono", :jp_sales 0.03, :global_sales 0.03} #user.Game{:game "FIFA Soccer 13", :jp_sales 0.03, :global_sales 5.16} #user.Game{:game "Sniper Elite 3", :jp_sales 0.0, :global_sales 0.35} #user.Game{:game "Dragon Ball Z: Budokai Tenkaichi 2", :jp_sales 0.0, :global_sales 0.79} #user.Game{:game "Disney's Magical Quest 2 Starring Mickey and Minnie", :jp_sales 0.0, :global_sales 0.06} #user.Game{:game "The Sims: Hot Date", :jp_sales 0.0, :global_sales 1.82} #user.Game{:game "We Sing Pop!", :jp_sales 0.0, :global_sales 0.22} #user.Game{:game "Spartan: Total Warrior", :jp_sales 0.0, :global_sales 0.13} #user.Game{:game "Batman: Arkham City", :jp_sales 0.0, :global_sales 0.53} #user.Game{:game "Downhill Domination", :jp_sales 0.0, :global_sales 0.47} #user.Game{:game "The Sims: Bustin' Out", :jp_sales 0.0, :global_sales 0.56} #user.Game{:game "Nora to Koku no Koubou: Kiri no Mori no Majo", :jp_sales 0.05, :global_sales 0.05} #user.Game{:game "P.T.O. IV: Pacific Theater of Operations", :jp_sales 0.0, :global_sales 0.08} #user.Game{:game "Barnyard", :jp_sales 0.0, :global_sales 0.09} #user.Game{:game "The Urbz: Sims in the City", :jp_sales 0.0, :global_sales 0.4} #user.Game{:game "Tales of Zestiria", :jp_sales 0.42, :global_sales 0.56} #user.Game{:game "Phineas and Ferb Ride Again", :jp_sales 0.0, :global_sales 0.29} #user.Game{:game "The History Channel: Battle for the Pacific", :jp_sales 0.0, :global_sales 0.0 ...
